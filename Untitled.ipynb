# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("1_housing.csv")
df.head()
# Out:
#    Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           0    -122.23     37.88                41.0        880.0
# 1           1    -122.22     37.86                 NaN       7099.0
# 2           2    -122.24     37.85                52.0       1467.0
# 3           3    -122.25     37.85                52.0          NaN
# 4           4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0             NaN       322.0         NaN         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY

# %%
df.tail()
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 20635       20635    -121.09     39.48                25.0       1665.0
# 20636       20636    -121.21     39.49                18.0        697.0
# 20637       20637    -121.22     39.43                17.0       2254.0
# 20638       20638    -121.32     39.43                18.0       1860.0
# 20639       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 20635           374.0       845.0       330.0         1.5603
# 20636           150.0         NaN         NaN         2.5568
# 20637           485.0      1007.0         NaN         1.7000
# 20638           409.0       741.0       349.0         1.8672
# 20639           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity
# 20635             78100.0          INLAND
# 20636                 NaN          INLAND
# 20637             92300.0          INLAND
# 20638             84700.0             NaN
# 20639             89400.0          INLAND

# %%
df.size
# Out:
# 227040

# %%
df.shape
# Out:
# (20640, 11)

# %%
# how to identify missing data
df.isnull().sum()
# Out:
# Unnamed: 0               0
# longitude             1049
# latitude               985
# housing_median_age    1008
# total_rooms           1038
# total_bedrooms        1233
# population            1043
# households            1012
# median_income         1003
# median_house_value    1092
# ocean_proximity       1049
# dtype: int64

# %% [markdown]
# # Removing the rows with missing values

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           0    -122.23     37.88                41.0        880.0
# 1           1    -122.22     37.86                 NaN       7099.0
# 2           2    -122.24     37.85                52.0       1467.0
# 3           3    -122.25     37.85                52.0          NaN
# 4           4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0             NaN       322.0         NaN         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0               0
# longitude             1049
# latitude               985
# housing_median_age    1008
# total_rooms           1038
# total_bedrooms        1233
# population            1043
# households            1012
# median_income         1003
# median_house_value    1092
# ocean_proximity       1049
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df2.size
# Out:
# 134453

# %%
df2.shape
# Out:
# (12223, 11)

# %% [markdown]
# # Imputation

# %% [markdown]
# # Replacing missing values with mean,mode,median

# %%
df3 = df.copy()

# %%
df3.head()
# Out:
#    Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           0    -122.23     37.88                41.0        880.0
# 1           1    -122.22     37.86                 NaN       7099.0
# 2           2    -122.24     37.85                52.0       1467.0
# 3           3    -122.25     37.85                52.0          NaN
# 4           4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0             NaN       322.0         NaN         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0               0
# longitude             1049
# latitude               985
# housing_median_age    1008
# total_rooms           1038
# total_bedrooms        1233
# population            1043
# households            1012
# median_income         1003
# median_house_value    1092
# ocean_proximity       1049
# dtype: int64

# %%
df3["longitude"].fillna(df3["longitude"].mean(), inplace=True)

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0               0
# longitude                0
# latitude               985
# housing_median_age    1008
# total_rooms           1038
# total_bedrooms        1233
# population            1043
# households            1012
# median_income         1003
# median_house_value    1092
# ocean_proximity       1049
# dtype: int64

# %%
df3.fillna(df3.mean(),inplace=True)
# Out:
# C:\Users\HP840G~1\AppData\Local\Temp/ipykernel_2972/3210759605.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3.fillna(df3.mean(),inplace=True)

# %%
# df3.fillna(df3[["longitude","latitude","total_rooms"]].mean(),inplace=True)

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0               0
# longitude                0
# latitude                 0
# housing_median_age       0
# total_rooms              0
# total_bedrooms           0
# population               0
# households               0
# median_income            0
# median_house_value       0
# ocean_proximity       1049
# dtype: int64

# %%
# !python --version
# Out:
# Python 3.9.7

# %%
df3["ocean_proximity"].mode()
# Out:
# 0    <1H OCEAN
# dtype: object

# %%
df3["ocean_proximity"].fillna(df3["ocean_proximity"].mode()[0],inplace=True)

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# # Forward and Backward filling

# %%
df5 = df.copy()

# %%
df5.ffill(inplace=True)

# %%
df5.bfill(inplace=True)

# %%
df5.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df5.head()
# Out:
#    Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           0    -122.23     37.88                41.0        880.0
# 1           1    -122.22     37.86                41.0       7099.0
# 2           2    -122.24     37.85                52.0       1467.0
# 3           3    -122.25     37.85                52.0       1467.0
# 4           4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0          1106.0       322.0      1138.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY

# %% [markdown]
# # interpulation

# %%
# just for numerical data not for categorical
df6 = df.copy()

# %%
df6.interpolate(method="linear",inplace=True)

# %%
df6.isnull().sum()
# Out:
# Unnamed: 0               0
# longitude                0
# latitude                 0
# housing_median_age       0
# total_rooms              0
# total_bedrooms           1
# population               0
# households               1
# median_income            0
# median_house_value       0
# ocean_proximity       1049
# dtype: int64

# %% [markdown]
# # Flagging

# %%
df7 = df.copy()

# %%
df7.columns
# Out:
# Index(['Unnamed: 0', 'longitude', 'latitude', 'housing_median_age',
#        'total_rooms', 'total_bedrooms', 'population', 'households',
#        'median_income', 'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df7["missing_house_price?"] = df7["median_house_value"].isnull().astype(int)

# %%
df7.tail()
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 20635       20635    -121.09     39.48                25.0       1665.0
# 20636       20636    -121.21     39.49                18.0        697.0
# 20637       20637    -121.22     39.43                17.0       2254.0
# 20638       20638    -121.32     39.43                18.0       1860.0
# 20639       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 20635           374.0       845.0       330.0         1.5603
# 20636           150.0         NaN         NaN         2.5568
# 20637           485.0      1007.0         NaN         1.7000
# 20638           409.0       741.0       349.0         1.8672
# 20639           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity  missing_house_price?
# 20635             78100.0          INLAND                     0
# 20636                 NaN          INLAND                     1
# 20637             92300.0          INLAND                     0
# 20638             84700.0             NaN                     0
# 20639             89400.0          INLAND                     0

# %%
df7.dtypes
# Out:
# Unnamed: 0                int64
# longitude               float64
# latitude                float64
# housing_median_age      float64
# total_rooms             float64
# total_bedrooms          float64
# population              float64
# households              float64
# median_income           float64
# median_house_value      float64
# ocean_proximity          object
# missing_house_price?      int32
# dtype: object

# %%
df3["population"] = df3["population"].astype(int)

# %%
df3.dtypes
# Out:
# Unnamed: 0              int64
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population              int32
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df3["ocean_proximity"].head()
# Out:
# 0    NEAR BAY
# 1    NEAR BAY
# 2    NEAR BAY
# 3    NEAR BAY
# 4    NEAR BAY
# Name: ocean_proximity, dtype: object

# %%
df3["ocean_proximity"] = df3["ocean_proximity"].str.lower()

# %%
df3["ocean_proximity"].head(25)
# Out:
# 0      near bay
# 1      near bay
# 2      near bay
# 3      near bay
# 4      near bay
# 5      near bay
# 6      near bay
# 7      near bay
# 8      near bay
# 9      near bay
# 10     near bay
# 11     near bay
# 12    <1h ocean
# 13     near bay
# 14     near bay
# 15     near bay
# 16     near bay
# 17     near bay
# 18     near bay
# 19     near bay
# 20     near bay
# 21     near bay
# 22     near bay
# 23     near bay
# 24     near bay
# Name: ocean_proximity, dtype: object

# %%
df3.nunique()
# Out:
# Unnamed: 0            20640
# longitude               842
# latitude                860
# housing_median_age       53
# total_rooms            5818
# total_bedrooms         1895
# population             3835
# households             1794
# median_income         12457
# median_house_value     3811
# ocean_proximity           5
# dtype: int64

# %%
df3["ocean_proximity"] = df3["ocean_proximity"].astype("category")

# %%
df3.dtypes
# Out:
# Unnamed: 0               int64
# longitude              float64
# latitude               float64
# housing_median_age     float64
# total_rooms            float64
# total_bedrooms         float64
# population               int32
# households             float64
# median_income          float64
# median_house_value     float64
# ocean_proximity       category
# dtype: object

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.drop_duplicates()
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               0    -122.23     37.88           41.000000   880.000000
# 1               1    -122.22     37.86           28.633812  7099.000000
# 2               2    -122.24     37.85           52.000000  1467.000000
# 3               3    -122.25     37.85           52.000000  2639.686001
# 4               4    -122.25     37.85           52.000000  1627.000000
# ...           ...        ...       ...                 ...          ...
# 20635       20635    -121.09     39.48           25.000000  1665.000000
# 20636       20636    -121.21     39.49           18.000000   697.000000
# 20637       20637    -121.22     39.43           17.000000  2254.000000
# 20638       20638    -121.32     39.43           18.000000  1860.000000
# 20639       20639    -121.24     39.37           16.000000  2785.000000
#
#        total_bedrooms  population   households  median_income  \
# 0          537.305714         322   500.791319         8.3252
# 1         1106.000000        2401  1138.000000         8.3014
# 2          190.000000         496   177.000000         7.2574
# 3          235.000000         558   219.000000         5.6431
# 4          280.000000         565   259.000000         3.8462
# ...               ...         ...          ...            ...
# 20635      374.000000         845   330.000000         1.5603
# 20636      150.000000        1426   500.791319         2.5568
# 20637      485.000000        1007   500.791319         1.7000
# 20638      409.000000         741   349.000000         1.8672
# 20639      616.000000        1387   530.000000         2.3886
#
#        median_house_value ocean_proximity
# 0           452600.000000        near bay
# 1           358500.000000        near bay
# 2           352100.000000        near bay
# 3           341300.000000        near bay
# 4           342200.000000        near bay
# ...                   ...             ...
# 20635        78100.000000          inland
# 20636       206889.804942          inland
# 20637        92300.000000          inland
# 20638        84700.000000       <1h ocean
# 20639        89400.000000          inland
#
# [20640 rows x 11 columns]

# %%
df3.drop(columns="Unnamed: 0",inplace=True)

# %%
df3.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000   880.000000      537.305714
# 1    -122.22     37.86           28.633812  7099.000000     1106.000000
# 2    -122.24     37.85           52.000000  1467.000000      190.000000
# 3    -122.25     37.85           52.000000  2639.686001      235.000000
# 4    -122.25     37.85           52.000000  1627.000000      280.000000
#
#    population   households  median_income  median_house_value ocean_proximity
# 0         322   500.791319         8.3252            452600.0        near bay
# 1        2401  1138.000000         8.3014            358500.0        near bay
# 2         496   177.000000         7.2574            352100.0        near bay
# 3         558   219.000000         5.6431            341300.0        near bay
# 4         565   259.000000         3.8462            342200.0        near bay

# %%
df3.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df3.rename(columns={"median_house_value":"house_price","median_income":"income"},inplace=True)

# %%
df3.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'income', 'house_price',
#        'ocean_proximity'],
#       dtype='object')

# %%
df3.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000   880.000000      537.305714
# 1    -122.22     37.86           28.633812  7099.000000     1106.000000
# 2    -122.24     37.85           52.000000  1467.000000      190.000000
# 3    -122.25     37.85           52.000000  2639.686001      235.000000
# 4    -122.25     37.85           52.000000  1627.000000      280.000000
#
#    population   households  income  house_price ocean_proximity
# 0         322   500.791319  8.3252     452600.0        near bay
# 1        2401  1138.000000  8.3014     358500.0        near bay
# 2         496   177.000000  7.2574     352100.0        near bay
# 3         558   219.000000  5.6431     341300.0        near bay
# 4         565   259.000000  3.8462     342200.0        near bay

# %% [markdown]
# # Feature Engineering

# %%
# house per year
df3["price_per_year"] = df3["house_price"] / df3["housing_median_age"]

# %%
df3.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000   880.000000      537.305714
# 1    -122.22     37.86           28.633812  7099.000000     1106.000000
# 2    -122.24     37.85           52.000000  1467.000000      190.000000
# 3    -122.25     37.85           52.000000  2639.686001      235.000000
# 4    -122.25     37.85           52.000000  1627.000000      280.000000
#
#    population   households  income  house_price ocean_proximity  \
# 0         322   500.791319  8.3252     452600.0        near bay
# 1        2401  1138.000000  8.3014     358500.0        near bay
# 2         496   177.000000  7.2574     352100.0        near bay
# 3         558   219.000000  5.6431     341300.0        near bay
# 4         565   259.000000  3.8462     342200.0        near bay
#
#    price_per_year
# 0    11039.024390
# 1    12520.163162
# 2     6771.153846
# 3     6563.461538
# 4     6580.769231

# %%
df3["rooms_per_household"] = df3["total_rooms"] / df3["households"]

# %%
df3.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000   880.000000      537.305714
# 1    -122.22     37.86           28.633812  7099.000000     1106.000000
# 2    -122.24     37.85           52.000000  1467.000000      190.000000
# 3    -122.25     37.85           52.000000  2639.686001      235.000000
# 4    -122.25     37.85           52.000000  1627.000000      280.000000
#
#    population   households  income  house_price ocean_proximity  \
# 0         322   500.791319  8.3252     452600.0        near bay
# 1        2401  1138.000000  8.3014     358500.0        near bay
# 2         496   177.000000  7.2574     352100.0        near bay
# 3         558   219.000000  5.6431     341300.0        near bay
# 4         565   259.000000  3.8462     342200.0        near bay
#
#    price_per_year  rooms_per_house_hold  rooms_per_household
# 0    11039.024390              1.757219             1.757219
# 1    12520.163162              6.238137             6.238137
# 2     6771.153846              8.288136             8.288136
# 3     6563.461538             12.053361            12.053361
# 4     6580.769231              6.281853             6.281853

# %%
df3.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.572050     35.623190           28.633812   2639.686001
# std        1.953756      2.082286           12.268593   2130.416839
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.660000     33.950000           19.000000   1484.000000
# 50%     -118.950000     34.430000           28.633812   2219.500000
# 75%     -118.040000     37.670000           37.000000   3074.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households        income  \
# count    20640.000000  20640.000000  20640.000000  20640.000000
# mean       537.305714   1426.724758    500.791319      3.869844
# std        406.738011   1107.660309    372.624621      1.848906
# min          2.000000      3.000000      1.000000      0.499900
# 25%        305.000000    807.000000    287.000000      2.608300
# 50%        456.000000   1212.000000    425.000000      3.634000
# 75%        628.000000   1683.250000    592.000000      4.666700
# max       6445.000000  35682.000000   6082.000000     15.000100
#
#          house_price  price_per_year  rooms_per_house_hold  \
# count   20640.000000    20640.000000          20640.000000
# mean   206889.804942     9860.961795              5.605923
# std    112124.528635    11949.859811              4.841399
# min     14999.000000      288.442308              0.035943
# 25%    123775.000000     4307.331731              4.394229
# 50%    186900.000000     6863.873626              5.229129
# 75%    258300.000000    11216.666667              6.107882
# max    500001.000000   250000.500000            439.947667
#
#        rooms_per_household
# count         20640.000000
# mean              5.605923
# std               4.841399
# min               0.035943
# 25%               4.394229
# 50%               5.229129
# 75%               6.107882
# max             439.947667

# %%
bins = [0,180000,250000,float("inf")]
labels = ["cheap","Economic/Moderate", "Expensive"]

df3["price_category"] = pd.cut(df3["house_price"],bins=bins,labels=labels)

# %%
df3.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000   880.000000      537.305714
# 1    -122.22     37.86           28.633812  7099.000000     1106.000000
# 2    -122.24     37.85           52.000000  1467.000000      190.000000
# 3    -122.25     37.85           52.000000  2639.686001      235.000000
# 4    -122.25     37.85           52.000000  1627.000000      280.000000
#
#    population   households  income  house_price ocean_proximity  \
# 0         322   500.791319  8.3252     452600.0        near bay
# 1        2401  1138.000000  8.3014     358500.0        near bay
# 2         496   177.000000  7.2574     352100.0        near bay
# 3         558   219.000000  5.6431     341300.0        near bay
# 4         565   259.000000  3.8462     342200.0        near bay
#
#    price_per_year  rooms_per_house_hold  rooms_per_household price_category
# 0    11039.024390              1.757219             1.757219      Expensive
# 1    12520.163162              6.238137             6.238137      Expensive
# 2     6771.153846              8.288136             8.288136      Expensive
# 3     6563.461538             12.053361            12.053361      Expensive
# 4     6580.769231              6.281853             6.281853      Expensive

# %%
bins = [0,12,30,float("inf")]
labels = ["New","Medium","Old"]

df3["age_category"] = pd.cut(df3["housing_median_age"],bins=bins, labels=labels)

# %%
df3.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000   880.000000      537.305714
# 1    -122.22     37.86           28.633812  7099.000000     1106.000000
# 2    -122.24     37.85           52.000000  1467.000000      190.000000
# 3    -122.25     37.85           52.000000  2639.686001      235.000000
# 4    -122.25     37.85           52.000000  1627.000000      280.000000
#
#    population   households  income  house_price ocean_proximity  \
# 0         322   500.791319  8.3252     452600.0        near bay
# 1        2401  1138.000000  8.3014     358500.0        near bay
# 2         496   177.000000  7.2574     352100.0        near bay
# 3         558   219.000000  5.6431     341300.0        near bay
# 4         565   259.000000  3.8462     342200.0        near bay
#
#    price_per_year  rooms_per_house_hold  rooms_per_household price_category  \
# 0    11039.024390              1.757219             1.757219      Expensive
# 1    12520.163162              6.238137             6.238137      Expensive
# 2     6771.153846              8.288136             8.288136      Expensive
# 3     6563.461538             12.053361            12.053361      Expensive
# 4     6580.769231              6.281853             6.281853      Expensive
#
#   age_category
# 0          Old
# 1       Medium
# 2          Old
# 3          Old
# 4          Old
